# %% [markdown]
# # Importing Library

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Preprocesing

# %%
df = pd.read_csv('train.csv')

# %%
x_test = pd.read_csv('test.csv')

# %%
df = pd.concat([df, x_test], axis=0)

# %%
y_test = pd.read_csv('gender_submission.csv')

# %%
x_train = df.drop(['Survived','Cabin','Name','Ticket'],axis=1)
y_train = df['Survived']

# %%
x_train['Embarked'].fillna(method='backfill',inplace=True)

# %%
x_train['Age'].fillna(method='backfill',inplace=True)

# %%
x_train.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Sex            0
# Age            2
# SibSp          0
# Parch          0
# Fare           1
# Embarked       0
# dtype: int64

# %%
x_train.head(10)
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1       3    male  22.0      1      0   7.2500        S
# 1            2       1  female  38.0      1      0  71.2833        C
# 2            3       3  female  26.0      0      0   7.9250        S
# 3            4       1  female  35.0      1      0  53.1000        S
# 4            5       3    male  35.0      0      0   8.0500        S
# 5            6       3    male  54.0      0      0   8.4583        Q
# 6            7       1    male  54.0      0      0  51.8625        S
# 7            8       3    male   2.0      3      1  21.0750        S
# 8            9       3  female  27.0      0      2  11.1333        S
# 9           10       2  female  14.0      1      0  30.0708        C

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1309 entries, 0 to 417
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Pclass       1309 non-null   int64
#  2   Sex          1309 non-null   object
#  3   Age          1307 non-null   float64
#  4   SibSp        1309 non-null   int64
#  5   Parch        1309 non-null   int64
#  6   Fare         1308 non-null   float64
#  7   Embarked     1309 non-null   object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 92.0+ KB

# %%
dummies = pd.get_dummies(x_train[['Sex', 'Embarked']],drop_first=True)

# %%
x_train = x_train.drop(columns=['Sex', 'Embarked'])

# %%
x_train = pd.concat([x_train, dummies], axis=1)

# %%
x_train
# Out:
#      PassengerId  Pclass   Age  SibSp  Parch      Fare  Sex_male  Embarked_Q  \
# 0              1       3  22.0      1      0    7.2500      True       False
# 1              2       1  38.0      1      0   71.2833     False       False
# 2              3       3  26.0      0      0    7.9250     False       False
# 3              4       1  35.0      1      0   53.1000     False       False
# 4              5       3  35.0      0      0    8.0500      True       False
# ..           ...     ...   ...    ...    ...       ...       ...         ...
# 413         1305       3  39.0      0      0    8.0500      True       False
# 414         1306       1  39.0      0      0  108.9000     False       False
# 415         1307       3  38.5      0      0    7.2500      True       False
# 416         1308       3   NaN      0      0    8.0500      True       False
# 417         1309       3   NaN      1      1   22.3583      True       False
#
#      Embarked_S
# 0          True
# ...

# %%
ss = StandardScaler()

# %%
X_scaled = ss.fit_transform(x_train)

# %%
X_scaled
# Out:
# array([[-1.73072813,  0.84191642, -0.54476133, ...,  0.74349692,
#         -0.32204029,  0.65620202],
#        [-1.72808175, -1.54609786,  0.56027046, ..., -1.34499549,
#         -0.32204029, -1.52392094],
#        [-1.72543538,  0.84191642, -0.26850339, ..., -1.34499549,
#         -0.32204029,  0.65620202],
#        ...,
#        [ 1.72543538,  0.84191642,  0.5948027 , ...,  0.74349692,
#         -0.32204029,  0.65620202],
#        [ 1.72808175,  0.84191642,         nan, ...,  0.74349692,
#         -0.32204029,  0.65620202],
#        [ 1.73072813,  0.84191642,         nan, ...,  0.74349692,
#         -0.32204029, -1.52392094]], shape=(1309, 9))

# %% [markdown]
# # Applying Model

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(X_scaled,y_train)
# Out:
# LogisticRegression()

# %%
# x_test = x_test.drop(['Cabin','Name','Ticket'],axis=1)

# %%
# Out:
#      PassengerId  Pclass   Age  SibSp  Parch      Fare  Sex_male  Embarked_Q  \
# 0            892       3  34.5      0      0    7.8292      True        True
# 1            893       3  47.0      1      0    7.0000     False       False
# 2            894       2  62.0      0      0    9.6875      True        True
# 3            895       3  27.0      0      0    8.6625      True       False
# 4            896       3  22.0      1      1   12.2875     False       False
# ..           ...     ...   ...    ...    ...       ...       ...         ...
# 413         1305       3   NaN      0      0    8.0500      True       False
# 414         1306       1  39.0      0      0  108.9000     False       False
# 415         1307       3  38.5      0      0    7.2500      True       False
# 416         1308       3   NaN      0      0    8.0500      True       False
# 417         1309       3   NaN      1      1   22.3583      True       False
#
#      Embarked_S
# 0         False
# ...
