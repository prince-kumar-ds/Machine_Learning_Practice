# %%
class PrinceLR:

    def __init__(self):
        self.m=None
        self.b=None


    def fit(self,x_train,y_train):
        numerator = 0
        denominator = 0
        
        for i in range(x_train.shape[0]):
            numerator = numerator + ((x_train[i]- x_train.mean())*(y_train[i]-y_train.mean()))
            denominator = denominator + (x_train[i]-x_train.mean())*(x_train[i]-x_train.mean())
        self.m = numerator/denominator
        self.b = y_train.mean()-(self.m*x_train.mean())
        print(f"coef......{self.m}")
        print(f"intercept........{self.b}")

            
            
    def predict(self,x_test):
        z = self.m*x_test + self.b
        return z

    def MyR2_score(self,y_test,y_pred):
        L = []
        residual = (y_test-y_pred)
        residual_sq = residual**2
        rss = residual_sq.sum()
        print(rss)
        tss = ((y_test - y_test.mean())**2).sum()
        print(tss)
        r2 = 1 -(rss/tss)
        return f"your r2 score is {r2}"

# %%
import pandas as pd
import numpy as np 
from sklearn.model_selection import train_test_split

# %%
df = pd.read_excel('placement.xlsx')

# %%
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
x = df.iloc[:,0].values
y = df.iloc[:,1].values

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
 # for i in range(x_train.shape[0]+1):
 #     # print(i)

# %%
lr = PrinceLR()

# %%
lr.fit(x_train,y_train)
# Out:
# coef......0.5742564727019197
# intercept........-1.0270069374542108

# %%
y_pred_train = lr.predict(x_train)

# %%
y_pred_train
# Out:
# array([3.09615454, 3.11338223, 3.92308386, 2.72288783, 1.9131862 ,
#        2.95259042, 3.07892684, 3.26843148, 1.75813696, 3.34308482,
#        2.32665086, 2.84922425, 3.50387663, 2.36684882, 3.06169915,
#        3.81971769, 3.51536176, 3.38902534, 2.95259042, 3.05595658,
#        4.31932082, 2.40704677, 3.62447049, 4.10684593, 2.91813503,
#        3.2167484 , 2.38981908, 3.63021306, 3.05595658, 2.21179957,
#        4.290608  , 2.86645195, 2.14863136, 2.92962016, 3.22249096,
#        2.95833298, 3.74506435, 3.1018971 , 3.53833202, 2.08546314,
#        3.46367868, 4.13555875, 2.45872985, 2.56783858, 3.15358018,
#        1.72368157, 3.16506531, 2.41278933, 2.52764063, 2.11991853,
#        2.4989278 , 2.85496682, 2.82625399, 2.61952166, 2.76882835,
#        3.50387663, 3.97476694, 2.83773912, 2.08546314, 1.97635441,
#        2.95833298, 2.96981811, 2.95259042, 2.32665086, 3.43496586,
#        2.5161555 , 2.0280375 , 2.6137791 , 3.9001136 , 2.45872985,
# ...

# %% [markdown]
# R2 score on Training

# %%
lr.MyR2_score(y_train, y_pred_train)
# Out:
# 18.013242797348134
# 80.35667749999999
# 'your r2 score is 0.7758339025733345'

# %% [markdown]
# Now r2 score on testing

# %%
y_pred_test = lr.predict(x_test)
y_pred_test.shape
# Out:
# (40,)

# %%
lr.MyR2_score(y_test,y_pred_test)
# Out:
# 3.3670553445318623
# 14.8392775
# 'your r2 score is 0.7730984312051673'

# %%
y_test.shape
# Out:
# (40,)

# %% [markdown]
# If we compare both r2 scores on traing and testing this shows that my model is well balanced with Low bias and Low varaince

# %%
This side Prince Kumar
